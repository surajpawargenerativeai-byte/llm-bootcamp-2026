# %%
import tiktoken

# %%
enc = tiktoken.get_encoding("o200k_base")

# %%
assert enc.decode(enc.encode("hello world")) == "hello world"

# %%
print("roundtrip OK")
# Out:
# roundtrip OK

# %%
ids = enc.encode("Tokenizers turn text into integers.")

# %%
print(len(ids), ids)
# Out:
# 7 [4421, 24223, 3716, 2201, 1511, 54912, 13]

# %%
pieces = [enc.decode_single_token_bytes(t) for t in ids]

# %%
for t, p in zip(ids, pieces):
    print(f"{t:>7}   {p}")
# Out:
#    4421   b'Token'
#   24223   b'izers'
#    3716   b' turn'
#    2201   b' text'
#    1511   b' into'
#   54912   b' integers'
#      13   b'.'

# %%
def show(s):
    ids = enc.encode(s)
    print(f"{len(ids):>3} tok | {s!r} -> {[enc.decode_single_token_bytes(t) for t in ids]}")

show("hello")
show(" hello")                         
show("Hello"); show("HELLO")           
show("1234567890")                      
show("$1,234.56")                       
show("        indented")                
show("नमस्ते")                            
show("🤖💸")                             
show("antidisestablishmentarianism")
# Out:
#   1 tok | 'hello' -> [b'hello']
#   1 tok | ' hello' -> [b' hello']
#   1 tok | 'Hello' -> [b'Hello']
#   2 tok | 'HELLO' -> [b'HEL', b'LO']
#   4 tok | '1234567890' -> [b'123', b'456', b'789', b'0']
#   6 tok | '$1,234.56' -> [b'$', b'1', b',', b'234', b'.', b'56']
#   3 tok | '        indented' -> [b'       ', b' ind', b'ented']
#   4 tok | 'नमस्ते' -> [b'\xe0\xa4\xa8', b'\xe0\xa4\xae', b'\xe0\xa4\xb8\xe0\xa5\x8d\xe0\xa4\xa4', b'\xe0\xa5\x87']
#   4 tok | '🤖💸' -> [b'\xf0\x9f\xa4', b'\x96', b'\xf0\x9f\x92', b'\xb8']
#   6 tok | 'antidisestablishmentarianism' -> [b'ant', b'idis', b'est', b'ablishment', b'arian', b'ism']

# %%
text = "The model estimates the borrower's probablity of default."

# %%
for name in ["gpt2", "cl100k_base", "o200k_base"]:
    e = tiktoken.get_encoding(name)
    print(f"{name:>12}: {len(e.encode(text))} tokens")
# Out:
#         gpt2: 12 tokens
#  cl100k_base: 12 tokens
#   o200k_base: 12 tokens

# %%
print(tiktoken.list_encoding_names())
# Out:
# ['gpt2', 'r50k_base', 'p50k_base', 'p50k_edit', 'cl100k_base', 'o200k_base', 'o200k_harmony']

# %%
# %% 4 — Special tokens + a token/cost helper
try:
    enc.encode("<|endoftext|>")                       # refused by default...
except ValueError as err:
    print("blocked:", err)                            # ...so user text can't inject it

print(enc.encode("<|endoftext|>", allowed_special="all"))   # opt in explicitly

def count_and_cost(s, price_per_1k=0.0025):
    n = len(enc.encode(s))
    return n, n / 1000 * price_per_1k

print(count_and_cost("Summarize the Q3 credit-risk report in three bullets."))

# %%
try:
    enc.encode("<|endoftext|>")
except ValueError as err:
    print("blocked:", err)
# Out:
# blocked: Encountered text corresponding to disallowed special token '<|endoftext|>'.
# If you want this text to be encoded as a special token, pass it to `allowed_special`, e.g. `allowed_special={'<|endoftext|>', ...}`.
# If you want this text to be encoded as normal text, disable the check for this token by passing `disallowed_special=(enc.special_tokens_set - {'<|endoftext|>'})`.
# To disable this check for all special tokens, pass `disallowed_special=()`.

# %%
print(enc.encode("<|endoftext|>", allowed_special = "all"))
# Out:
# [199999]

# %%
def count_and_cost(s, price_per_1k = 0.0025):
    n = len(enc.encode(s))
    return n, n / 1000 * price_per_1k

# %%
print(count_and_cost("Summerize the Q3 credit-risk report in three bullets."))
# Out:
# (12, 3e-05)

# %%
from tiktoken._educational import SimpleBytePairEncoding, train_simple_encoding

# %%
vis = SimpleBytePairEncoding.from_tiktoken("cl100k_base")

# %%
vis.encode("hello world aaaaaaaaaaaaaaaa")
# Out:
# hello
# hello
# hello
# hello
# hello
#
#  world
#  world
#  world
#  world
#  world
#  world
#
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
#  aaaaaaaaaaaaaaaa
# [15339, 1917, 264, 70540, 29558, 33746]

# %%
toy = train_simple_encoding()
# Out:
# The current most common pair is b' ' + b' '
# So we made b'  ' our 257th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'  ' + b'  '
# So we made b'    ' our 258th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'  ' + b' '
# So we made b'   ' our 259th token
# Now the first fifty words in our training data look like:
# ...
